# %% [markdown]
# <a href="https://colab.research.google.com/github/bharat-mullapudi/LSTM_SOC_RUL/blob/main/GreatRes_att2dec17R3implementation_1_SOC_LSTM_CALCE_IC2_25deg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
import seaborn as sns

# %%
df = pd.read_excel('/content/drive/MyDrive/LSTM_SOC_Implementation/calce_incremental_INR_18650-20R/Incremental_temp_25.xlsx')

# %%
df
# Out:
#          Test_Time(s)  Cycle_Index  ...  TimeDelta       SOC
# 0           10.000502          1.0  ...          1      0.97
# 1           20.016109          1.0  ...    10.0156  0.984508
# 2           30.031595          1.0  ...    10.0155  0.984604
# 3           40.047191          1.0  ...    10.0156  0.984604
# 4           50.062737          1.0  ...    10.0155  0.984604
# ...               ...          ...  ...        ...       ...
# 1048568           NaN          NaN  ...
# 1048569           NaN          NaN  ...
# 1048570           NaN          NaN  ...
# 1048571           NaN          NaN  ...
# 1048572           NaN          NaN  ...
#
# [1048573 rows x 8 columns]

# %%
df=df.dropna()

# %%
combined_data=df

# %%
combined_data.to_csv('Incremental_Init_25.csv')
combined_data=pd.read_csv('Incremental_Init_25.csv')

# %%
combined_data.describe()
# Out:
#           Unnamed: 0   Test_Time(s)  ...      TimeDelta            SOC
# count  142119.000000  142119.000000  ...  142119.000000  142119.000000
# mean    71059.000000   78705.582922  ...       1.058963       0.691114
# std     41026.365791   41479.490967  ...       0.660660       0.118811
# min         0.000000      10.000167  ...       0.000000       0.000000
# 25%     35529.500000   42831.169001  ...       1.000083       0.633504
# 50%     71059.000000   78728.254274  ...       1.015559       0.672399
# 75%    106588.500000  114616.556029  ...       1.015613       0.787366
# max    142118.000000  150507.800260  ...      10.017162       0.988512
#
# [8 rows x 9 columns]

# %%
###
combined_data=combined_data.drop_duplicates()
#combined_data.set_index('Data_Point',inplace=True)
#cd2=combined_data.drop(63990)
#cdcombined_data.drop(127979)

#cd2=combined_data;

# %%
combined_data
# Out:
#         Unnamed: 0   Test_Time(s)  ...  TimeDelta       SOC
# 0                0      10.000167  ...   1.000000  0.970000
# 1                1      20.015713  ...  10.015546  0.980028
# 2                2      30.031239  ...  10.015526  0.980028
# 3                3      40.046793  ...  10.015553  0.980123
# 4                4      50.062341  ...  10.015548  0.980028
# ...            ...            ...  ...        ...       ...
# 142114      142114  150503.768645  ...   1.015622  0.889110
# 142115      142115  150504.768729  ...   1.000084  0.889249
# 142116      142116  150505.784258  ...   1.015528  0.889390
# 142117      142117  150506.784411  ...   1.000153  0.889528
# 142118      142118  150507.800260  ...   1.015849  0.889669
#
# [142119 rows x 9 columns]

# %%
combined_data=combined_data.iloc[:,1:] #drop first column
combined_data.shape
combined_data
# Out:
#          Test_Time(s)  Cycle_Index  ...  TimeDelta       SOC
# 0           10.000167          1.0  ...   1.000000  0.970000
# 1           20.015713          1.0  ...  10.015546  0.980028
# 2           30.031239          1.0  ...  10.015526  0.980028
# 3           40.046793          1.0  ...  10.015553  0.980123
# 4           50.062341          1.0  ...  10.015548  0.980028
# ...               ...          ...  ...        ...       ...
# 142114  150503.768645         18.0  ...   1.015622  0.889110
# 142115  150504.768729         18.0  ...   1.000084  0.889249
# 142116  150505.784258         18.0  ...   1.015528  0.889390
# 142117  150506.784411         18.0  ...   1.000153  0.889528
# 142118  150507.800260         18.0  ...   1.015849  0.889669
#
# [142119 rows x 8 columns]

# %%
#combined_data.to_csv('cd.csv')
#files.download('cd.csv')

# %%
combined_data=combined_data.drop(columns=['Charge_Capacity(Ah)','Discharge_Capacity(Ah)','TimeDelta'])

# %%
combined_data.hist()
plt.figure(figsize=(20,20))
plt.show()

# %%
combined_data=combined_data.drop(columns=['Test_Time(s)'])

# %%
  fig = plt.figure(figsize = (15,15))
  ax = fig.gca()
  combined_data.hist(ax = ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff4d0fc4650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff4d20446d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff4d248dc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff4d27ca2d0>]],
#       dtype=object)

# %%
correlations = combined_data.corr()
plt.figure(figsize=(8,8))
sns.heatmap(correlations, cmap='RdBu_r')
plt.show()

# %%
combined_data.describe()
# Out:
#          Cycle_Index     Current(A)     Voltage(V)            SOC
# count  142119.000000  142119.000000  142119.000000  142119.000000
# mean        9.029032      -0.007765       3.684208       0.691114
# std         4.802561       0.303031       0.207378       0.118811
# min         1.000000      -1.000233       2.499903       0.000000
# 25%         5.000000       0.000000       3.577119       0.633504
# 50%         9.000000       0.000000       3.661715       0.672399
# 75%        13.000000       0.000000       3.839495       0.787366
# max        18.000000       0.999904       4.375753       0.988512

# %% [markdown]
# Deleting 0 valued columns

# %%
#cd2=pd.read_csv('/content/drive/MyDrive/LSTM_SOC_Implementation/r1.csv')
cd2=combined_data
cd2.describe()
# Out:
#          Cycle_Index     Current(A)     Voltage(V)            SOC
# count  142119.000000  142119.000000  142119.000000  142119.000000
# mean        9.029032      -0.007765       3.684208       0.691114
# std         4.802561       0.303031       0.207378       0.118811
# min         1.000000      -1.000233       2.499903       0.000000
# 25%         5.000000       0.000000       3.577119       0.633504
# 50%         9.000000       0.000000       3.661715       0.672399
# 75%        13.000000       0.000000       3.839495       0.787366
# max        18.000000       0.999904       4.375753       0.988512

# %%
cd2
# Out:
#         Cycle_Index  Current(A)  Voltage(V)       SOC
# 0               1.0    0.000000    4.166209  0.970000
# 1               1.0    0.000000    4.166047  0.980028
# 2               1.0    0.000000    4.166047  0.980028
# 3               1.0    0.000000    4.166209  0.980123
# 4               1.0    0.000000    4.166047  0.980028
# ...             ...         ...         ...       ...
# 142114         18.0    0.999544    4.249022  0.889110
# 142115         18.0    0.999364    4.249184  0.889249
# 142116         18.0    0.999544    4.249508  0.889390
# 142117         18.0    0.999544    4.249671  0.889528
# 142118         18.0    0.999544    4.249832  0.889669
#
# [142119 rows x 4 columns]

# %%
y = cd2.SOC
X = cd2.drop(['SOC'], axis=1)

# %%
X.describe()
# Out:
#          Cycle_Index     Current(A)     Voltage(V)
# count  142119.000000  142119.000000  142119.000000
# mean        9.029032      -0.007765       3.684208
# std         4.802561       0.303031       0.207378
# min         1.000000      -1.000233       2.499903
# 25%         5.000000       0.000000       3.577119
# 50%         9.000000       0.000000       3.661715
# 75%        13.000000       0.000000       3.839495
# max        18.000000       0.999904       4.375753

# %% [markdown]
# split

# %%
cd2.values
# Out:
# array([[ 1.        ,  0.        ,  4.16620922,  0.97      ],
#        [ 1.        ,  0.        ,  4.1660471 ,  0.9800277 ],
#        [ 1.        ,  0.        ,  4.1660471 ,  0.9800277 ],
#        ...,
#        [18.        ,  0.99954402,  4.24950838,  0.88938957],
#        [18.        ,  0.99954402,  4.24967051,  0.88952842],
#        [18.        ,  0.99954402,  4.24983215,  0.88966944]])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
dataset = cd2.SOC.values #numpy.ndarray
dataset = dataset.astype('float64')
dataset = np.reshape(dataset, (-1, 1))
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.80)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# %%
# reshape into X=t and Y=t+1
look_back = 3

X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)

# %%
X_train
# Out:
# array([[0.98127282, 0.99141706, 0.99141706],
#        [0.99141706, 0.99141706, 0.99151354],
#        [0.99141706, 0.99151354, 0.99141706],
#        ...,
#        [0.69930767, 0.69950048, 0.69930767],
#        [0.69950048, 0.69930767, 0.6992112 ],
#        [0.69930767, 0.6992112 , 0.69930767]])

# %%
X_train.shape
# Out:
# (113691, 3)

# %%
Y_train.shape
# Out:
# (113691,)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
import math
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.callbacks import EarlyStopping

# %%
model = Sequential()
#model.add(LSTM(,return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.1))
model.add(Dense(2))
model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=(X_test, Y_test), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=50)], verbose=1, shuffle=False)

# Training Phase
model.summary()
# Out:
# Epoch 1/100
# 1777/1777 [==============================] - 9s 4ms/step - loss: 0.0203 - val_loss: 6.2112e-04
# Epoch 2/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 8.5071e-04
# Epoch 3/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 0.0010 - val_loss: 9.0748e-04
# Epoch 4/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 8.1428e-04 - val_loss: 0.0015
# Epoch 5/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 7.3410e-04 - val_loss: 0.0019
# Epoch 6/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 6.4870e-04 - val_loss: 0.0015
# Epoch 7/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 5.4244e-04 - val_loss: 0.0012
# Epoch 8/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 4.2461e-04 - val_loss: 8.1354e-04
# Epoch 9/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 3.1587e-04 - val_loss: 4.6097e-04
# Epoch 10/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 2.3784e-04 - val_loss: 4.1894e-04
# Epoch 11/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.9203e-04 - val_loss: 3.1500e-04
# Epoch 12/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.6717e-04 - val_loss: 3.8866e-04
# Epoch 13/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.5419e-04 - val_loss: 4.5512e-04
# Epoch 14/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.5744e-04 - val_loss: 5.5094e-04
# Epoch 15/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.5911e-04 - val_loss: 6.4178e-04
# Epoch 16/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.5925e-04 - val_loss: 6.7594e-04
# Epoch 17/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.6001e-04 - val_loss: 6.9575e-04
# Epoch 18/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.5646e-04 - val_loss: 8.3831e-04
# Epoch 19/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.6673e-04 - val_loss: 7.7248e-04
# Epoch 20/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.5510e-04 - val_loss: 8.3698e-04
# Epoch 21/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.6003e-04 - val_loss: 7.3860e-04
# Epoch 22/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.5181e-04 - val_loss: 8.4456e-04
# Epoch 23/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.5419e-04 - val_loss: 7.8135e-04
# Epoch 24/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.4941e-04 - val_loss: 7.9714e-04
# Epoch 25/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.4780e-04 - val_loss: 7.7416e-04
# Epoch 26/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.4604e-04 - val_loss: 7.1146e-04
# Epoch 27/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.3923e-04 - val_loss: 7.6171e-04
# Epoch 28/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.4313e-04 - val_loss: 7.5858e-04
# Epoch 29/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.3801e-04 - val_loss: 7.1609e-04
# Epoch 30/100
# 1777/1777 [==============================] - 6s 4ms/step - loss: 1.3794e-04 - val_loss: 8.1362e-04
# Epoch 31/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.4225e-04 - val_loss: 7.1920e-04
# Epoch 32/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.2745e-04 - val_loss: 6.6229e-04
# Epoch 33/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.2718e-04 - val_loss: 6.4156e-04
# Epoch 34/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.2405e-04 - val_loss: 7.4012e-04
# Epoch 35/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.3101e-04 - val_loss: 6.8650e-04
# Epoch 36/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.2785e-04 - val_loss: 7.0383e-04
# Epoch 37/100
# 1777/1777 [==============================] - 6s 4ms/step - loss: 1.2567e-04 - val_loss: 6.7978e-04
# Epoch 38/100
# 1777/1777 [==============================] - 6s 4ms/step - loss: 1.2037e-04 - val_loss: 5.6783e-04
# Epoch 39/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.1316e-04 - val_loss: 6.7110e-04
# Epoch 40/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.2440e-04 - val_loss: 6.6202e-04
# Epoch 41/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.2309e-04 - val_loss: 6.0287e-04
# Epoch 42/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.1489e-04 - val_loss: 6.4375e-04
# Epoch 43/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.1525e-04 - val_loss: 5.9420e-04
# Epoch 44/100
# 1777/1777 [==============================] - 6s 3ms/step - loss: 1.1345e-04 - val_loss: 6.7770e-04
# Epoch 45/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.2013e-04 - val_loss: 5.9262e-04
# Epoch 46/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.1292e-04 - val_loss: 6.0163e-04
# Epoch 47/100
# 1777/1777 [==============================] - 6s 4ms/step - loss: 1.1282e-04 - val_loss: 6.2880e-04
# Epoch 48/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.1546e-04 - val_loss: 5.8597e-04
# Epoch 49/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.1034e-04 - val_loss: 5.8773e-04
# Epoch 50/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.1270e-04 - val_loss: 5.7510e-04
# Epoch 51/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.1201e-04 - val_loss: 5.8043e-04
# Epoch 52/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.0878e-04 - val_loss: 5.3548e-04
# Epoch 53/100
# 1777/1777 [==============================] - 6s 4ms/step - loss: 1.0749e-04 - val_loss: 6.4672e-04
# Epoch 54/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.1425e-04 - val_loss: 5.8008e-04
# Epoch 55/100
# 1777/1777 [==============================] - 6s 4ms/step - loss: 1.1119e-04 - val_loss: 6.0992e-04
# Epoch 56/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.1301e-04 - val_loss: 5.3873e-04
# Epoch 57/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.1046e-04 - val_loss: 7.3475e-04
# Epoch 58/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.2027e-04 - val_loss: 5.3654e-04
# Epoch 59/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.0772e-04 - val_loss: 5.8441e-04
# Epoch 60/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.1223e-04 - val_loss: 6.4094e-04
# Epoch 61/100
# 1777/1777 [==============================] - 7s 4ms/step - loss: 1.1484e-04 - val_loss: 6.0513e-04
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                10800
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 10,902
# Trainable params: 10,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
Y_train = scaler.inverse_transform([Y_train])
test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])

print('Train Mean Absolute Error:', mean_absolute_error(Y_train[0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_train[0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(Y_test[0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test[0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 0.012532890548755646
# Train Root Mean Squared Error: 0.020521774951570208
# Test Mean Absolute Error: 0.020227271912268977
# Test Root Mean Squared Error: 0.024317925676767955

# %%
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
aa=[x for x in range(20000)]
plt.figure(figsize=(20,4))
plt.plot(aa, Y_test[0][:20000], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:20000], 'r', label="prediction")
plt.tick_params(left=False, labelleft=True) #remove ticks
#plt.tight_layout()
#sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('SOC', size=15)
plt.ylim((0,1))
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %%
aa=[x for x in range(110000)]
plt.figure(figsize=(20,4))
plt.plot(aa, Y_train[0][:110000], marker='.', label="actual")
plt.plot(aa, train_predict[:,0][:110000], 'r', label="prediction")
plt.tick_params(left=False, labelleft=True) #remove ticks
#plt.tight_layout()
#sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('SOC', size=15)
plt.ylim((0,1))
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();
