# %% [markdown]
# <a href="https://colab.research.google.com/github/bharat-mullapudi/LSTM_SOC_RUL/blob/main/dec18_att2dec17R3implementation_1_SOC_LSTM_CALCE_IC2_0deg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
import seaborn as sns

# %%
df = pd.read_excel('/content/drive/MyDrive/LSTM_SOC_Implementation/calce_incremental_INR_18650-20R/Incremental_temp_0.xlsx')

# %%
df
# Out:
#          Test_Time(s)  Cycle_Index  ...  TimeDelta       SOC
# 0           10.000019          1.0  ...          1      0.97
# 1           20.015468          1.0  ...    10.0154  0.978693
# 2           30.030954          1.0  ...    10.0155  0.978693
# 3           40.046428          1.0  ...    10.0155  0.978693
# 4           50.061910          1.0  ...    10.0155  0.978788
# ...               ...          ...  ...        ...       ...
# 1048569           NaN          NaN  ...
# 1048570           NaN          NaN  ...
# 1048571           NaN          NaN  ...
# 1048572           NaN          NaN  ...
# 1048573           NaN          NaN  ...
#
# [1048574 rows x 8 columns]

# %%
df=df.dropna()

# %%
combined_data=df

# %%
combined_data.to_csv('Incremental_Init_0.csv')
combined_data=pd.read_csv('Incremental_Init_0.csv')

# %%
combined_data.describe()
# Out:
#           Unnamed: 0   Test_Time(s)  ...      TimeDelta            SOC
# count  157570.000000  157570.000000  ...  157570.000000  157570.000000
# mean    78784.500000   86648.264899  ...       1.055854       0.736358
# std     45486.685295   46052.526517  ...       0.628872       0.121619
# min         0.000000      10.000019  ...       0.000000       0.045320
# 25%     39392.250000   46807.431234  ...       1.015400       0.646755
# 50%     78784.500000   86664.620077  ...       1.015584       0.701856
# 75%    118176.750000  126522.511848  ...       1.015615       0.851428
# max    157569.000000  166379.962373  ...      10.017561       1.000000
#
# [8 rows x 9 columns]

# %%
###
#combined_data=combined_data.drop_duplicates()
#combined_data.set_index('Data_Point',inplace=True)
#cd2=combined_data.drop(63990)
#cdcombined_data.drop(127979)

#cd2=combined_data;

# %%
combined_data
# Out:
#         Unnamed: 0   Test_Time(s)  ...  TimeDelta       SOC
# 0                0      10.000019  ...   1.000000  0.970000
# 1                1      20.015468  ...  10.015450  0.978693
# 2                2      30.030954  ...  10.015485  0.978693
# 3                3      40.046428  ...  10.015474  0.978693
# 4                4      50.061910  ...  10.015482  0.978788
# ...            ...            ...  ...        ...       ...
# 157565      157565  166376.509256  ...   1.015608  0.978502
# 157566      157566  166377.524866  ...   1.015610  0.978598
# 157567      157567  166378.540471  ...   1.015605  0.978598
# 157568      157568  166379.556097  ...   1.015626  0.978598
# 157569      157569  166379.962373  ...   0.406276  0.978598
#
# [157570 rows x 9 columns]

# %%
combined_data=combined_data.iloc[:,1:] #drop first column
combined_data.shape
combined_data
# Out:
#          Test_Time(s)  Cycle_Index  ...  TimeDelta       SOC
# 0           10.000019          1.0  ...   1.000000  0.970000
# 1           20.015468          1.0  ...  10.015450  0.978693
# 2           30.030954          1.0  ...  10.015485  0.978693
# 3           40.046428          1.0  ...  10.015474  0.978693
# 4           50.061910          1.0  ...  10.015482  0.978788
# ...               ...          ...  ...        ...       ...
# 157565  166376.509256         19.0  ...   1.015608  0.978502
# 157566  166377.524866         19.0  ...   1.015610  0.978598
# 157567  166378.540471         19.0  ...   1.015605  0.978598
# 157568  166379.556097         19.0  ...   1.015626  0.978598
# 157569  166379.962373         19.0  ...   0.406276  0.978598
#
# [157570 rows x 8 columns]

# %%
combined_data=combined_data.drop(columns=['Charge_Capacity(Ah)','Discharge_Capacity(Ah)','TimeDelta'])

# %%
combined_data.hist()
plt.figure(figsize=(20,20))
plt.show()

# %%
combined_data=combined_data.drop(columns=['Test_Time(s)'])

# %%
  fig = plt.figure(figsize = (15,15))
  ax = fig.gca()
  combined_data.hist(ax = ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf283ecad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b577390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b562510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2a5c7b50>]],
#       dtype=object)

# %%
correlations = combined_data.corr()
plt.figure(figsize=(8,8))
sns.heatmap(correlations, cmap='RdBu_r')
plt.show()

# %%
combined_data.describe()
# Out:
#          Cycle_Index     Current(A)     Voltage(V)            SOC
# count  157570.000000  157570.000000  157570.000000  157570.000000
# mean       10.490157      -0.000120       3.756622       0.736358
# std         5.748668       0.280592       0.209131       0.121619
# min         1.000000      -1.000412       2.577044       0.045320
# 25%         5.000000       0.000000       3.600780       0.646755
# 50%        11.000000       0.000000       3.694451       0.701856
# 75%        16.000000       0.000000       3.950466       0.851428
# max        19.000000       0.999904       4.262149       1.000000

# %% [markdown]
# Deleting 0 valued columns

# %%
#cd2=pd.read_csv('/content/drive/MyDrive/LSTM_SOC_Implementation/r1.csv')
cd2=combined_data
cd2.describe()
# Out:
#          Cycle_Index     Current(A)     Voltage(V)            SOC
# count  157570.000000  157570.000000  157570.000000  157570.000000
# mean       10.490157      -0.000120       3.756622       0.736358
# std         5.748668       0.280592       0.209131       0.121619
# min         1.000000      -1.000412       2.577044       0.045320
# 25%         5.000000       0.000000       3.600780       0.646755
# 50%        11.000000       0.000000       3.694451       0.701856
# 75%        16.000000       0.000000       3.950466       0.851428
# max        19.000000       0.999904       4.262149       1.000000

# %%
cd2
# Out:
#         Cycle_Index  Current(A)  Voltage(V)       SOC
# 0               1.0         0.0    4.163778  0.970000
# 1               1.0         0.0    4.163778  0.978693
# 2               1.0         0.0    4.163778  0.978693
# 3               1.0         0.0    4.163778  0.978693
# 4               1.0         0.0    4.163940  0.978788
# ...             ...         ...         ...       ...
# 157565         19.0         0.0    4.163454  0.978502
# 157566         19.0         0.0    4.163616  0.978598
# 157567         19.0         0.0    4.163616  0.978598
# 157568         19.0         0.0    4.163616  0.978598
# 157569         19.0         0.0    4.163616  0.978598
#
# [157570 rows x 4 columns]

# %%
y = cd2.SOC
X = cd2.drop(['SOC'], axis=1)

# %%
X.describe()
# Out:
#          Cycle_Index     Current(A)     Voltage(V)
# count  157570.000000  157570.000000  157570.000000
# mean       10.490157      -0.000120       3.756622
# std         5.748668       0.280592       0.209131
# min         1.000000      -1.000412       2.577044
# 25%         5.000000       0.000000       3.600780
# 50%        11.000000       0.000000       3.694451
# 75%        16.000000       0.000000       3.950466
# max        19.000000       0.999904       4.262149

# %% [markdown]
# split

# %%
cd2.values
# Out:
# array([[ 1.        ,  0.        ,  4.16377831,  0.97      ],
#        [ 1.        ,  0.        ,  4.16377831,  0.97869312],
#        [ 1.        ,  0.        ,  4.16377831,  0.97869312],
#        ...,
#        [19.        ,  0.        ,  4.16361618,  0.97859775],
#        [19.        ,  0.        ,  4.16361618,  0.97859775],
#        [19.        ,  0.        ,  4.16361618,  0.97859775]])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
dataset = cd2.SOC.values #numpy.ndarray
dataset = dataset.astype('float64')
dataset = np.reshape(dataset, (-1, 1))
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.80)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# %%
# reshape into X=t and Y=t+1
look_back = 3

X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)

# %%
X_train
# Out:
# array([[0.96857586, 0.97768166, 0.97768166],
#        [0.97768166, 0.97768166, 0.97768166],
#        [0.97768166, 0.97768166, 0.97778155],
#        ...,
#        [0.8012376 , 0.8012376 , 0.8012376 ],
#        [0.8012376 , 0.8012376 , 0.8012376 ],
#        [0.8012376 , 0.8012376 , 0.80113771]])

# %%
X_train.shape
# Out:
# (126052, 3)

# %%
Y_train.shape
# Out:
# (126052,)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
import math
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

# %%
model = Sequential()
#model.add(LSTM(,return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.1))
model.add(Dense(2))
model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=(X_test, Y_test), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=50), ModelCheckpoint(filepath='best_model0.h5', monitor='val_loss', save_best_only=True)], verbose=1, shuffle=False)
#scores = model.evaluate(X_test, Y_test, verbose=1)
#print("Accuracy: %.2f%%" % (scores[1]*100))
# Training Phase
model.summary()
# Out:
# Epoch 1/100
# 1970/1970 [==============================] - 9s 3ms/step - loss: 0.0177 - val_loss: 4.5434e-04
# Epoch 2/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 0.0012 - val_loss: 7.5565e-04
# Epoch 3/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 8.9336e-04 - val_loss: 0.0015
# Epoch 4/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 6.9093e-04 - val_loss: 0.0016
# Epoch 5/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 5.8306e-04 - val_loss: 0.0017
# Epoch 6/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 5.0820e-04 - val_loss: 0.0017
# Epoch 7/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 4.2524e-04 - val_loss: 0.0014
# Epoch 8/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 3.3395e-04 - val_loss: 0.0015
# Epoch 9/100
# 1970/1970 [==============================] - 7s 4ms/step - loss: 2.4233e-04 - val_loss: 0.0012
# Epoch 10/100
# 1970/1970 [==============================] - 7s 3ms/step - loss: 1.7499e-04 - val_loss: 0.0013
# Epoch 11/100
# 1970/1970 [==============================] - 7s 3ms/step - loss: 1.5190e-04 - val_loss: 0.0019
# Epoch 12/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.5655e-04 - val_loss: 0.0019
# Epoch 13/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.6523e-04 - val_loss: 0.0021
# Epoch 14/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.7080e-04 - val_loss: 0.0021
# Epoch 15/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.8661e-04 - val_loss: 0.0021
# Epoch 16/100
# 1970/1970 [==============================] - 7s 3ms/step - loss: 1.9255e-04 - val_loss: 0.0021
# Epoch 17/100
# 1970/1970 [==============================] - 7s 3ms/step - loss: 1.8729e-04 - val_loss: 0.0022
# Epoch 18/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 2.0225e-04 - val_loss: 0.0021
# Epoch 19/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.9848e-04 - val_loss: 0.0021
# Epoch 20/100
# 1970/1970 [==============================] - 7s 3ms/step - loss: 1.9664e-04 - val_loss: 0.0021
# Epoch 21/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.9418e-04 - val_loss: 0.0021
# Epoch 22/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.9472e-04 - val_loss: 0.0020
# Epoch 23/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.8765e-04 - val_loss: 0.0020
# Epoch 24/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.8638e-04 - val_loss: 0.0019
# Epoch 25/100
# 1970/1970 [==============================] - 7s 4ms/step - loss: 1.7790e-04 - val_loss: 0.0019
# Epoch 26/100
# 1970/1970 [==============================] - 7s 4ms/step - loss: 1.7193e-04 - val_loss: 0.0018
# Epoch 27/100
# 1970/1970 [==============================] - 7s 4ms/step - loss: 1.6234e-04 - val_loss: 0.0017
# Epoch 28/100
# 1970/1970 [==============================] - 7s 4ms/step - loss: 1.5330e-04 - val_loss: 0.0017
# Epoch 29/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.4343e-04 - val_loss: 0.0017
# Epoch 30/100
# 1970/1970 [==============================] - 7s 4ms/step - loss: 1.4915e-04 - val_loss: 0.0016
# Epoch 31/100
# 1970/1970 [==============================] - 7s 3ms/step - loss: 1.3324e-04 - val_loss: 0.0016
# Epoch 32/100
# 1970/1970 [==============================] - 7s 4ms/step - loss: 1.3499e-04 - val_loss: 0.0015
# Epoch 33/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.2741e-04 - val_loss: 0.0015
# Epoch 34/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.1713e-04 - val_loss: 0.0015
# Epoch 35/100
# 1970/1970 [==============================] - 7s 4ms/step - loss: 1.1814e-04 - val_loss: 0.0015
# Epoch 36/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.1384e-04 - val_loss: 0.0014
# Epoch 37/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.0844e-04 - val_loss: 0.0014
# Epoch 38/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.1154e-04 - val_loss: 0.0014
# Epoch 39/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.0369e-04 - val_loss: 0.0015
# Epoch 40/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 1.0252e-04 - val_loss: 0.0013
# Epoch 41/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 9.7859e-05 - val_loss: 0.0014
# Epoch 42/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 9.6855e-05 - val_loss: 0.0014
# Epoch 43/100
# 1970/1970 [==============================] - 7s 3ms/step - loss: 1.0089e-04 - val_loss: 0.0014
# Epoch 44/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 9.6716e-05 - val_loss: 0.0013
# Epoch 45/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 9.0776e-05 - val_loss: 0.0014
# Epoch 46/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 9.1521e-05 - val_loss: 0.0014
# Epoch 47/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 8.7204e-05 - val_loss: 0.0014
# Epoch 48/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 8.7274e-05 - val_loss: 0.0014
# Epoch 49/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 8.5885e-05 - val_loss: 0.0014
# Epoch 50/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 8.4013e-05 - val_loss: 0.0014
# Epoch 51/100
# 1970/1970 [==============================] - 6s 3ms/step - loss: 8.6610e-05 - val_loss: 0.0014
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 50)                10800
#
#  dropout_6 (Dropout)         (None, 50)                0
#
#  dense_6 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 10,902
# Trainable params: 10,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
'''from keras.models import load_model
saved_model = load_model('best_model45.h5')
train_acc = saved_model.evaluate(X_train, Y_train, verbose=0)
test_acc = saved_model.evaluate(X_test, Y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))'''

# %%
# make predictions
from keras.models import load_model
saved_model = load_model('best_model45.h5')
train_predict = saved_model.predict(X_train)
test_predict = saved_model.predict(X_test)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
Y_train = scaler.inverse_transform([Y_train])
test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])

print('Train Mean Absolute Error:', mean_absolute_error(Y_train[0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_train[0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(Y_test[0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test[0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 0.009052819953582075
# Train Root Mean Squared Error: 0.012541559527130512
# Test Mean Absolute Error: 0.026210086671261786
# Test Root Mean Squared Error: 0.027320845484824937

# %%
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
aa=[x for x in range(20000)]
plt.figure(figsize=(20,4))
plt.plot(aa, Y_test[0][:20000], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:20000], 'r', label="prediction")
plt.tick_params(left=False, labelleft=True) #remove ticks
#plt.tight_layout()
#sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('SOC', size=15)
plt.ylim((0,1))
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %%
aa=[x for x in range(110000)]
plt.figure(figsize=(20,4))
plt.plot(aa, Y_train[0][:110000], marker='.', label="actual")
plt.plot(aa, train_predict[:,0][:110000], 'r', label="prediction")
plt.tick_params(left=False, labelleft=True) #remove ticks
#plt.tight_layout()
#sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('SOC', size=15)
plt.ylim((0,1))
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();
