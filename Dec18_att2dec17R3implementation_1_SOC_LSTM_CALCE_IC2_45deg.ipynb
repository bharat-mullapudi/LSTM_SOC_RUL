# %% [markdown]
# <a href="https://colab.research.google.com/github/bharat-mullapudi/LSTM_SOC_RUL/blob/main/Dec18_att2dec17R3implementation_1_SOC_LSTM_CALCE_IC2_45deg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
import seaborn as sns

# %%
df = pd.read_excel('/content/drive/MyDrive/LSTM_SOC_Implementation/calce_incremental_INR_18650-20R/Incremental_temp_45.xlsx')

# %%
df
# Out:
#          Test_Time(s)  Cycle_Index  ...  TimeDelta       SOC
# 0           10.000502          1.0  ...          1      0.97
# 1           20.016109          1.0  ...    10.0156  0.984508
# 2           30.031595          1.0  ...    10.0155  0.984604
# 3           40.047191          1.0  ...    10.0156  0.984604
# 4           50.062737          1.0  ...    10.0155  0.984604
# ...               ...          ...  ...        ...       ...
# 1048568           NaN          NaN  ...
# 1048569           NaN          NaN  ...
# 1048570           NaN          NaN  ...
# 1048571           NaN          NaN  ...
# 1048572           NaN          NaN  ...
#
# [1048573 rows x 8 columns]

# %%
df=df.dropna()

# %%
combined_data=df

# %%
combined_data.to_csv('Incremental_Init_45.csv')
combined_data=pd.read_csv('Incremental_Init_45.csv')

# %%
combined_data.describe()
# Out:
#           Unnamed: 0   Test_Time(s)  ...      TimeDelta            SOC
# count  159107.000000  159107.000000  ...  159107.000000  159107.000000
# mean    79553.000000   87279.243341  ...       1.054046       0.722902
# std     45930.378977   46456.798733  ...       0.621824       0.134872
# min         0.000000      10.000502  ...       0.000435       0.314054
# 25%     39776.500000   47094.959959  ...       1.000212       0.633599
# 50%     79553.000000   87297.368555  ...       1.015569       0.693371
# 75%    119329.500000  127494.672648  ...       1.015621       0.850189
# max    159106.000000  167715.033539  ...      10.017457       1.000000
#
# [8 rows x 9 columns]

# %%
###
combined_data=combined_data.drop_duplicates()
#combined_data.set_index('Data_Point',inplace=True)
#cd2=combined_data.drop(63990)
#cdcombined_data.drop(127979)

#cd2=combined_data;

# %%
combined_data
# Out:
#         Unnamed: 0   Test_Time(s)  ...  TimeDelta       SOC
# 0                0      10.000502  ...   1.000000  0.970000
# 1                1      20.016109  ...  10.015606  0.984508
# 2                2      30.031595  ...  10.015487  0.984604
# 3                3      40.047191  ...  10.015596  0.984604
# 4                4      50.062737  ...  10.015546  0.984604
# ...            ...            ...  ...        ...       ...
# 159102      159102  167711.283616  ...   1.015685  0.986319
# 159103      159103  167712.283619  ...   1.000003  0.986224
# 159104      159104  167713.299187  ...   1.015567  0.986224
# 159105      159105  167714.314787  ...   1.015600  0.986224
# 159106      159106  167715.033539  ...   0.718753  0.986224
#
# [159107 rows x 9 columns]

# %%
combined_data=combined_data.iloc[:,1:] #drop first column
combined_data.shape
combined_data
# Out:
#          Test_Time(s)  Cycle_Index  ...  TimeDelta       SOC
# 0           10.000502          1.0  ...   1.000000  0.970000
# 1           20.016109          1.0  ...  10.015606  0.984508
# 2           30.031595          1.0  ...  10.015487  0.984604
# 3           40.047191          1.0  ...  10.015596  0.984604
# 4           50.062737          1.0  ...  10.015546  0.984604
# ...               ...          ...  ...        ...       ...
# 159102  167711.283616         19.0  ...   1.015685  0.986319
# 159103  167712.283619         19.0  ...   1.000003  0.986224
# 159104  167713.299187         19.0  ...   1.015567  0.986224
# 159105  167714.314787         19.0  ...   1.015600  0.986224
# 159106  167715.033539         19.0  ...   0.718753  0.986224
#
# [159107 rows x 8 columns]

# %%
combined_data=combined_data.drop(columns=['Charge_Capacity(Ah)','Discharge_Capacity(Ah)','TimeDelta'])

# %%
combined_data.hist()
plt.figure(figsize=(20,20))
plt.show()

# %%
combined_data=combined_data.drop(columns=['Test_Time(s)'])

# %%
  fig = plt.figure(figsize = (15,15))
  ax = fig.gca()
  combined_data.hist(ax = ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcfbc00dd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcfbca4a750>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcfbcf83d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcfbd0be390>]],
#       dtype=object)

# %%
correlations = combined_data.corr()
plt.figure(figsize=(8,8))
sns.heatmap(correlations, cmap='RdBu_r')
plt.show()

# %%
combined_data.describe()
# Out:
#          Cycle_Index     Current(A)     Voltage(V)            SOC
# count  159107.000000  159107.000000  159107.000000  159107.000000
# mean       10.493090       0.000390       3.735026       0.722902
# std         5.747789       0.295084       0.231053       0.134872
# min         1.000000      -1.000233       3.033892       0.314054
# 25%         5.000000       0.000000       3.578578       0.633599
# 50%        11.000000       0.000000       3.678893       0.693371
# 75%        16.000000       0.000000       3.946941       0.850189
# max        19.000000       1.001522       4.328594       1.000000

# %% [markdown]
# Deleting 0 valued columns

# %%
#cd2=pd.read_csv('/content/drive/MyDrive/LSTM_SOC_Implementation/r1.csv')
cd2=combined_data
cd2.describe()
# Out:
#          Cycle_Index     Current(A)     Voltage(V)            SOC
# count  159107.000000  159107.000000  159107.000000  159107.000000
# mean       10.493090       0.000390       3.735026       0.722902
# std         5.747789       0.295084       0.231053       0.134872
# min         1.000000      -1.000233       3.033892       0.314054
# 25%         5.000000       0.000000       3.578578       0.633599
# 50%        11.000000       0.000000       3.678893       0.693371
# 75%        16.000000       0.000000       3.946941       0.850189
# max        19.000000       1.001522       4.328594       1.000000

# %%
cd2
# Out:
#         Cycle_Index  Current(A)  Voltage(V)       SOC
# 0               1.0         0.0    4.173664  0.970000
# 1               1.0         0.0    4.173664  0.984508
# 2               1.0         0.0    4.173826  0.984604
# 3               1.0         0.0    4.173826  0.984604
# 4               1.0         0.0    4.173826  0.984604
# ...             ...         ...         ...       ...
# 159102         19.0         0.0    4.176743  0.986319
# 159103         19.0         0.0    4.176581  0.986224
# 159104         19.0         0.0    4.176581  0.986224
# 159105         19.0         0.0    4.176581  0.986224
# 159106         19.0         0.0    4.176581  0.986224
#
# [159107 rows x 4 columns]

# %%
y = cd2.SOC
X = cd2.drop(['SOC'], axis=1)

# %%
X.describe()
# Out:
#          Cycle_Index     Current(A)     Voltage(V)
# count  159107.000000  159107.000000  159107.000000
# mean       10.493090       0.000390       3.735026
# std         5.747789       0.295084       0.231053
# min         1.000000      -1.000233       3.033892
# 25%         5.000000       0.000000       3.578578
# 50%        11.000000       0.000000       3.678893
# 75%        16.000000       0.000000       3.946941
# max        19.000000       1.001522       4.328594

# %% [markdown]
# split

# %%
cd2.values
# Out:
# array([[ 1.        ,  0.        ,  4.17366409,  0.97      ],
#        [ 1.        ,  0.        ,  4.17366409,  0.98450829],
#        [ 1.        ,  0.        ,  4.17382622,  0.98460366],
#        ...,
#        [19.        ,  0.        ,  4.17658091,  0.98622406],
#        [19.        ,  0.        ,  4.17658091,  0.98622406],
#        [19.        ,  0.        ,  4.17658091,  0.98622406]])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
dataset = cd2.SOC.values #numpy.ndarray
dataset = dataset.astype('float64')
dataset = np.reshape(dataset, (-1, 1))
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.80)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# %%
# reshape into X=t and Y=t+1
look_back = 3

X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)

# %%
X_train
# Out:
# array([[0.95626476, 0.97741554, 0.97755457],
#        [0.97741554, 0.97755457, 0.97755457],
#        [0.97755457, 0.97755457, 0.97755457],
#        ...,
#        [0.70224374, 0.70210471, 0.70224374],
#        [0.70210471, 0.70224374, 0.70210471],
#        [0.70224374, 0.70210471, 0.70210471]])

# %%
X_train.shape
# Out:
# (127281, 3)

# %%
Y_train.shape
# Out:
# (127281,)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
import math
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# %%
model = Sequential()
#model.add(LSTM(,return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.1))
model.add(Dense(2))
model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=(X_test, Y_test), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=50), ModelCheckpoint(filepath='best_model45.h5', monitor='val_loss', save_best_only=True)], verbose=1, shuffle=False)
#scores = model.evaluate(X_test, Y_test, verbose=1)
#print("Accuracy: %.2f%%" % (scores[1]*100))
# Training Phase
model.summary()
# Out:
# Epoch 1/100
# 1989/1989 [==============================] - 9s 4ms/step - loss: 0.0169 - val_loss: 9.1553e-04
# Epoch 2/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 0.0010 - val_loss: 7.2694e-04
# Epoch 3/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 6.8490e-04 - val_loss: 0.0012
# Epoch 4/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 5.4454e-04 - val_loss: 0.0017
# Epoch 5/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 4.4742e-04 - val_loss: 0.0015
# Epoch 6/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 3.5081e-04 - val_loss: 0.0013
# Epoch 7/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 2.6450e-04 - val_loss: 8.2222e-04
# Epoch 8/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 2.0885e-04 - val_loss: 6.3312e-04
# Epoch 9/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.7619e-04 - val_loss: 6.8278e-04
# Epoch 10/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.6367e-04 - val_loss: 9.5613e-04
# Epoch 11/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.4775e-04 - val_loss: 0.0011
# Epoch 12/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.3388e-04 - val_loss: 0.0012
# Epoch 13/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.3295e-04 - val_loss: 0.0013
# Epoch 14/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.2435e-04 - val_loss: 0.0013
# Epoch 15/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.2177e-04 - val_loss: 0.0016
# Epoch 16/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.2134e-04 - val_loss: 0.0014
# Epoch 17/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.1074e-04 - val_loss: 0.0018
# Epoch 18/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.1544e-04 - val_loss: 0.0015
# Epoch 19/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.0874e-04 - val_loss: 0.0019
# Epoch 20/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.1430e-04 - val_loss: 0.0015
# Epoch 21/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.0804e-04 - val_loss: 0.0020
# Epoch 22/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.1267e-04 - val_loss: 0.0018
# Epoch 23/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.0639e-04 - val_loss: 0.0019
# Epoch 24/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.0935e-04 - val_loss: 0.0020
# Epoch 25/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.0764e-04 - val_loss: 0.0019
# Epoch 26/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.0535e-04 - val_loss: 0.0023
# Epoch 27/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.1441e-04 - val_loss: 0.0020
# Epoch 28/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.0394e-04 - val_loss: 0.0020
# Epoch 29/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.0594e-04 - val_loss: 0.0021
# Epoch 30/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.0783e-04 - val_loss: 0.0020
# Epoch 31/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.0186e-04 - val_loss: 0.0025
# Epoch 32/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.1146e-04 - val_loss: 0.0022
# Epoch 33/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.0944e-04 - val_loss: 0.0024
# Epoch 34/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.1119e-04 - val_loss: 0.0024
# Epoch 35/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.0951e-04 - val_loss: 0.0026
# Epoch 36/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.1415e-04 - val_loss: 0.0024
# Epoch 37/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.1172e-04 - val_loss: 0.0025
# Epoch 38/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.1360e-04 - val_loss: 0.0027
# Epoch 39/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.1742e-04 - val_loss: 0.0026
# Epoch 40/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.1217e-04 - val_loss: 0.0028
# Epoch 41/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.1942e-04 - val_loss: 0.0026
# Epoch 42/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.1538e-04 - val_loss: 0.0029
# Epoch 43/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.2172e-04 - val_loss: 0.0027
# Epoch 44/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.2408e-04 - val_loss: 0.0029
# Epoch 45/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.2484e-04 - val_loss: 0.0029
# Epoch 46/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.2467e-04 - val_loss: 0.0029
# Epoch 47/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.2708e-04 - val_loss: 0.0029
# Epoch 48/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.3136e-04 - val_loss: 0.0029
# Epoch 49/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.3023e-04 - val_loss: 0.0031
# Epoch 50/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.3450e-04 - val_loss: 0.0030
# Epoch 51/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.2923e-04 - val_loss: 0.0031
# Epoch 52/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.3181e-04 - val_loss: 0.0032
# Epoch 53/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.3798e-04 - val_loss: 0.0031
# Epoch 54/100
# 1989/1989 [==============================] - 7s 4ms/step - loss: 1.3535e-04 - val_loss: 0.0031
# Epoch 55/100
# 1989/1989 [==============================] - 6s 3ms/step - loss: 1.3607e-04 - val_loss: 0.0031
# Epoch 56/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.3572e-04 - val_loss: 0.0031
# Epoch 57/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.3695e-04 - val_loss: 0.0032
# Epoch 58/100
# 1989/1989 [==============================] - 7s 3ms/step - loss: 1.3536e-04 - val_loss: 0.0033
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 50)                10800
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense_2 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 10,902
# Trainable params: 10,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
'''from keras.models import load_model
saved_model = load_model('best_model45.h5')
train_acc = saved_model.evaluate(X_train, Y_train, verbose=0)
test_acc = saved_model.evaluate(X_test, Y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))'''
# Out:
# Train: 0.001, Test: 0.001

# %%
# make predictions
saved_model = load_model('best_model45.h5')
train_predict = saved_model.predict(X_train)
test_predict = saved_model.predict(X_test)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
Y_train = scaler.inverse_transform([Y_train])
test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])

print('Train Mean Absolute Error:', mean_absolute_error(Y_train[0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_train[0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(Y_test[0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test[0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 0.015778747107616366
# Train Root Mean Squared Error: 0.019512803265306404
# Test Mean Absolute Error: 0.014952282050284692
# Test Root Mean Squared Error: 0.017199858247106726

# %%
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
aa=[x for x in range(20000)]
plt.figure(figsize=(20,4))
plt.plot(aa, Y_test[0][:20000], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:20000], 'r', label="prediction")
plt.tick_params(left=False, labelleft=True) #remove ticks
#plt.tight_layout()
#sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('SOC', size=15)
plt.ylim((0,1))
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %%
aa=[x for x in range(110000)]
plt.figure(figsize=(20,4))
plt.plot(aa, Y_train[0][:110000], marker='.', label="actual")
plt.plot(aa, train_predict[:,0][:110000], 'r', label="prediction")
plt.tick_params(left=False, labelleft=True) #remove ticks
#plt.tight_layout()
#sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('SOC', size=15)
plt.ylim((0,1))
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();
