# %% [markdown]
# <a href="https://colab.research.google.com/github/bharat-mullapudi/LSTM_SOC_RUL/blob/main/implementation_1_SOC_LSTM_CALCE3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
import seaborn as sns
sns.set_style('darkgrid')

# %%
df = pd.read_excel('/content/drive/MyDrive/LSTM_SOC_Implementation/12_2_2015_Incremental_OCV_test_SP20-1.xlsx')

# %%
df
# Out:
#   Unnamed: 0           Unnamed: 1  ...     Unnamed: 21       Unnamed: 22
# 0        NaN                  NaN  ...             NaN               NaN
# 1        NaN                  NaN  ...             NaN               NaN
# 2    Channel       Start_DateTime  ...  Digital Output  Related Humidity
# 3      1-005  2015-12-02 10:08:38  ...               0               NaN
# 4      1-006  2015-12-02 10:08:38  ...               0               NaN
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (5, 23)

# %%
ws1 = pd.read_excel('/content/drive/MyDrive/LSTM_SOC_Implementation/12_2_2015_Incremental_OCV_test_SP20-1.xlsx', sheet_name = 1)
ws2 = pd.read_excel('/content/drive/MyDrive/LSTM_SOC_Implementation/12_2_2015_Incremental_OCV_test_SP20-1.xlsx', sheet_name = 2)
ws3 = pd.read_excel('/content/drive/MyDrive/LSTM_SOC_Implementation/12_2_2015_Incremental_OCV_test_SP20-1.xlsx', sheet_name = 3)

# %%
combined_data=ws1.append(ws2,ignore_index=True).append(ws3,ignore_index=True)
combined_data.shape
# Out:
# (142121, 19)

# %%
combined_data
# Out:
#         Data_Point   Test_Time(s)  ... AC_Impedance(Ohm)  ACI_Phase_Angle(Deg)
# 0                1      10.000167  ...                 0                     0
# 1                2      20.015713  ...                 0                     0
# 2                3      30.031239  ...                 0                     0
# 3                4      40.046793  ...                 0                     0
# 4                5      50.062341  ...                 0                     0
# ...            ...            ...  ...               ...                   ...
# 142116      142115  150503.768645  ...                 0                     0
# 142117      142116  150504.768729  ...                 0                     0
# 142118      142117  150505.784258  ...                 0                     0
# 142119      142118  150506.784411  ...                 0                     0
# 142120      142119  150507.800260  ...                 0                     0
#
# [142121 rows x 19 columns]

# %%
combined_data=combined_data.drop(columns=['SoC.1'])

# %%
combined_data.describe()
# Out:
#           Data_Point   Test_Time(s)  ...  AC_Impedance(Ohm)  ACI_Phase_Angle(Deg)
# count  142121.000000  142121.000000  ...           142121.0              142121.0
# mean    71060.350750   78706.392361  ...                0.0                   0.0
# std     41026.359223   41479.760320  ...                0.0                   0.0
# min         1.000000      10.000167  ...                0.0                   0.0
# 25%     35531.000000   42831.669001  ...                0.0                   0.0
# 50%     71060.000000   78729.254299  ...                0.0                   0.0
# 75%    106590.000000  114618.079463  ...                0.0                   0.0
# max    142119.000000  150507.800260  ...                0.0                   0.0
#
# [8 rows x 17 columns]

# %%
combined_data.to_csv('merged0.csv')

# %%
files.download('merged0.csv')

# %% [markdown]
# **63990, 127979 are repeated in datapoints**

# %%
combined_data=combined_data.drop_duplicates(subset=['Data_Point'])
combined_data.set_index('Data_Point',inplace=True)
#cd2=combined_data.drop(63990)
#cdcombined_data.drop(127979)

#cd2=combined_data;

# %%
combined_data.shape
combined_data
# Out:
#              Test_Time(s)  ... ACI_Phase_Angle(Deg)
# Data_Point                 ...
# 1               10.000167  ...                    0
# 2               20.015713  ...                    0
# 3               30.031239  ...                    0
# 4               40.046793  ...                    0
# 5               50.062341  ...                    0
# ...                   ...  ...                  ...
# 142115      150503.768645  ...                    0
# 142116      150504.768729  ...                    0
# 142117      150505.784258  ...                    0
# 142118      150506.784411  ...                    0
# 142119      150507.800260  ...                    0
#
# [142119 rows x 17 columns]

# %%
combined_data.to_csv('cd.csv')
files.download('cd.csv')

# %%
display(combined_data.loc[63990])
# Out:
# Test_Time(s)                            71585.2
# Date_Time                   2015-12-03 06:01:47
# Step_Time(s)                            510.184
# Step_Index                                    5
# Cycle_Index                                   9
# Current(A)                            -0.999873
# Voltage(V)                              3.23388
# Charge_Capacity(Ah)                   0.0161462
# Discharge_Capacity(Ah)                  1.74142
# SoC                                    0.407708
# Charge_Energy(Wh)                     0.0678237
# Discharge_Energy(Wh)                    6.13017
# dV/dt(V/s)                         -0.000129652
# Internal_Resistance(Ohm)                      0
# Is_FC_Data                                    0
# AC_Impedance(Ohm)                             0
# ACI_Phase_Angle(Deg)                          0
# Name: 63990, dtype: object

# %%
combined_data.hist()
plt.figure(figsize=(20,20))
plt.show()

# %%
  fig = plt.figure(figsize = (15,15))
  ax = fig.gca()
  combined_data.hist(ax = ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ffb82ee8310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb842cd890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb8483ad90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb84d2d350>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffb85083890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb80056450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb802e79d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb80719e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffb80719e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb80bd2490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb81267d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb8152d2d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffb819527d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb821f5cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb828d6190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb83043650>]],
#       dtype=object)

# %%
correlations = combined_data.corr()
plt.figure(figsize=(8,8))
sns.heatmap(correlations, cmap='RdBu_r')
plt.show()

# %%
combined_data.describe()
# Out:
#         Test_Time(s)   Step_Time(s)  ...  AC_Impedance(Ohm)  ACI_Phase_Angle(Deg)
# count  142119.000000  142119.000000  ...           142119.0              142119.0
# mean    78706.037752    3301.148810  ...                0.0                   0.0
# std     41479.767284    2192.907274  ...                0.0                   0.0
# min        10.000167       0.000005  ...                0.0                   0.0
# 25%     42831.169001    1251.741121  ...                0.0                   0.0
# 50%     78729.254299    3234.695696  ...                0.0                   0.0
# 75%    114617.571635    5217.752799  ...                0.0                   0.0
# max    150507.800260    7200.013696  ...                0.0                   0.0
#
# [8 rows x 16 columns]

# %% [markdown]
# Deleting 0 valued columns

# %%
combined_data=combined_data.drop(columns=['Internal_Resistance(Ohm)','Is_FC_Data','AC_Impedance(Ohm)',	'ACI_Phase_Angle(Deg)'])
combined_data.describe()

# %%
correlations = combined_data.corr()
plt.figure(figsize=(8,8))
sns.heatmap(correlations, cmap='RdBu_r')
plt.show()

# %%
  fig = plt.figure(figsize = (15,15))
  ax = fig.gca()
  combined_data.hist(ax = ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ffb8440ab50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb7fd75350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb7fc42810>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffb7fac7110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb7f6120d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb7fbe4450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffb7fc015d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb897f7890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb897f7990>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffb81f76d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb80143f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb81e79450>]],
#       dtype=object)

# %% [markdown]
# # ***Can run from here***
#
# ---

# %%
cd2=pd.read_csv('/content/drive/MyDrive/LSTM_SOC_Implementation/r1.csv')
cd2=cd2.drop_duplicates(subset=['Data_Point'])
cd2.describe()
# Out:
#           Data_Point   Test_Time(s)  ...  Charge_Energy(Wh)  Discharge_Energy(Wh)
# count  142119.000000  142119.000000  ...      142119.000000         142119.000000
# mean    71060.000000   78706.037752  ...           1.589229              5.207008
# std     41026.365791   41479.767284  ...           2.090072              2.114306
# min         1.000000      10.000167  ...           0.000000              0.000000
# 25%     35530.500000   42831.169000  ...           0.067824              3.647907
# 50%     71060.000000   78729.254300  ...           0.067824              6.317823
# 75%    106589.500000  114617.571650  ...           3.102921              6.892068
# max    142119.000000  150507.800300  ...           6.649329              6.892068
#
# [8 rows x 10 columns]

# %%
  fig = plt.figure(figsize = (12,12))
  ax = fig.gca()
  cd2.hist(ax = ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ffb8368c6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb80f3ead0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb8354a290>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffb83bd9c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb837bc710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb7ef4bd10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffb8132f190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb81737910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb81737950>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffb81f373d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb82610ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffb82e8bf10>]],
#       dtype=object)

# %%
correlations = cd2.corr()
plt.figure(figsize=(8,8))
sns.heatmap(correlations, cmap='RdBu_r')
plt.show()

# %%
y = cd2.SoC
X = cd2.drop(['Data_Point','Test_Time(s)','SoC'], axis=1)

# %%
X.describe()
# Out:
#          Cycle_Index     Current(A)  ...  Charge_Energy(Wh)  Discharge_Energy(Wh)
# count  142119.000000  142119.000000  ...      142119.000000         142119.000000
# mean        9.029081      -0.007758  ...           1.589229              5.207008
# std         4.802597       0.303019  ...           2.090072              2.114306
# min         1.000000      -1.000233  ...           0.000000              0.000000
# 25%         5.000000       0.000000  ...           0.067824              3.647907
# 50%         9.000000       0.000000  ...           0.067824              6.317823
# 75%        13.000000       0.000000  ...           3.102921              6.892068
# max        18.000000       0.999904  ...           6.649329              6.892068
#
# [8 rows x 7 columns]

# %%
y.describe()
# Out:
# count    142119.000000
# mean          0.657895
# std           0.115206
# min          -0.000054
# 25%           0.598400
# 50%           0.645397
# 75%           0.744164
# max           0.972129
# Name: SoC, dtype: float64

# %%
#split the dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size = 0.3, random_state = 11)

# %%
X_train[1:5]
# Out:
#        Cycle_Index  Current(A)  ...  Charge_Energy(Wh)  Discharge_Energy(Wh)
# 50137            7         0.0  ...           0.067824              5.000753
# 57930            8         0.0  ...           0.067824              5.666128
# 96499           12         0.0  ...           2.325117              6.892068
# 49181            7         0.0  ...           0.067824              5.000753
#
# [4 rows x 7 columns]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

#Creating Instance of StandarScaler
#scaler = MinMaxScaler()
#scaler = StandardScaler()
#Perform scaling in X_train with fit_transform.
#Here we are applying fit_transform because,
        # fit will calculate mean and standard deviation of X_train
        # transform will actually perform scaling with calculated mean and std.
        # fit_transform method does this both thing in one line of code.
X_train1 = scaler.fit_transform(X_train)

# Here we will only use transform because we have already calculated mean and std.
# Another reason is we don't want to know the mean and std of our test dataset As it
# Lead to information leakage.
X_test1 = scaler.transform(X_test)

# %%
X_train1[1:5]
# Out:
# array([[0.35294118, 0.50008222, 0.62582368, 0.00954253, 0.70433413,
#         0.01020189, 0.725581  ],
#        [0.41176471, 0.50008222, 0.60076108, 0.00954253, 0.80495919,
#         0.01020189, 0.82212311],
#        [0.64705882, 0.50008222, 0.6355703 , 0.36398502, 1.        ,
#         0.349739  , 1.        ],
#        [0.35294118, 0.50008222, 0.62406014, 0.00954253, 0.70433413,
#         0.01020189, 0.725581  ]])

# %%
a1=X_train1.shape[0]
a2=X_train1.shape[1]
a3=X_test1.shape[0]
a4=X_test1.shape[1]

# %%
X_train1
# Out:
# array([[0.60495156, 0.52941176, 0.50008222, ..., 1.        , 0.12107558,
#         1.        ],
#        [0.38259242, 0.35294118, 0.50008222, ..., 0.70433413, 0.01020189,
#         0.725581  ],
#        [0.43491065, 0.41176471, 0.50008222, ..., 0.80495919, 0.01020189,
#         0.82212311],
#        ...,
#        [0.19091954, 0.11764706, 0.50008222, ..., 0.301847  , 0.01020189,
#         0.32665175],
#        [0.2913361 , 0.23529412, 0.50008222, ..., 0.50309009, 0.01020189,
#         0.52929068],
#        [0.99390948, 0.94117647, 0.50008222, ..., 1.        , 0.95138796,
#         1.        ]])

# %%
# reshape input to be [samples, time steps, features]
X_train2 = np.reshape(X_train1, (a1, 1, a2))
X_test2 = np.reshape(X_test1, (a3,1, a4))

# %%
X_train2.shape
# Out:
# (99483, 1, 7)

# %%
y_train2=y_train.to_numpy()
y_train2
y_test2=y_test.to_numpy()
y_test2
# Out:
# array([0.63207216, 0.42418453, 0.70184814, ..., 0.69590595, 0.74965609,
#        0.70166813])

# %%
import math
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.callbacks import EarlyStopping

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train2.shape[1], X_train2.shape[2])))
model.add(Dropout(0.6))
model.add(Dense(2))
model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(X_train2, y_train2, epochs=20, batch_size=32, validation_data=(X_test2, y_test2), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=10)], verbose=1, shuffle=False)

# Training Phase
model.summary()
# Out:
# Epoch 1/20
# 3109/3109 [==============================] - 14s 4ms/step - loss: 0.0117 - val_loss: 4.2657e-04
# Epoch 2/20
# 3109/3109 [==============================] - 11s 4ms/step - loss: 8.6235e-04 - val_loss: 2.1861e-04
# Epoch 3/20
# 3109/3109 [==============================] - 11s 3ms/step - loss: 5.2859e-04 - val_loss: 2.5004e-05
# Epoch 4/20
# 3109/3109 [==============================] - 11s 3ms/step - loss: 4.6665e-04 - val_loss: 4.5772e-05
# Epoch 5/20
# 3109/3109 [==============================] - 11s 3ms/step - loss: 4.4693e-04 - val_loss: 2.6292e-05
# Epoch 6/20
# 3109/3109 [==============================] - 12s 4ms/step - loss: 4.4950e-04 - val_loss: 4.6290e-05
# Epoch 7/20
# 3109/3109 [==============================] - 11s 4ms/step - loss: 4.4417e-04 - val_loss: 1.3066e-05
# Epoch 8/20
# 3109/3109 [==============================] - 12s 4ms/step - loss: 4.3950e-04 - val_loss: 7.2503e-05
# Epoch 9/20
# 3109/3109 [==============================] - 12s 4ms/step - loss: 4.3521e-04 - val_loss: 5.8822e-05
# Epoch 10/20
# 3109/3109 [==============================] - 12s 4ms/step - loss: 4.3423e-04 - val_loss: 1.5970e-05
# Epoch 11/20
# 3109/3109 [==============================] - 11s 4ms/step - loss: 4.3638e-04 - val_loss: 4.8021e-05
# Epoch 12/20
# 3109/3109 [==============================] - 12s 4ms/step - loss: 4.2154e-04 - val_loss: 2.7129e-05
# Epoch 13/20
# 3109/3109 [==============================] - 12s 4ms/step - loss: 4.3447e-04 - val_loss: 9.8907e-06
# Epoch 14/20
# 3109/3109 [==============================] - 12s 4ms/step - loss: 4.2600e-04 - val_loss: 5.8240e-05
# Epoch 15/20
# 3109/3109 [==============================] - 12s 4ms/step - loss: 4.2998e-04 - val_loss: 5.3160e-05
# Epoch 16/20
# 3109/3109 [==============================] - 12s 4ms/step - loss: 4.2604e-04 - val_loss: 1.5674e-05
# Epoch 17/20
# 3109/3109 [==============================] - 11s 3ms/step - loss: 4.2967e-04 - val_loss: 2.5820e-05
# Epoch 18/20
# 3109/3109 [==============================] - 11s 3ms/step - loss: 4.2798e-04 - val_loss: 4.3465e-05
# Epoch 19/20
# 3109/3109 [==============================] - 11s 3ms/step - loss: 4.2472e-04 - val_loss: 2.0655e-05
# Epoch 20/20
# 3109/3109 [==============================] - 12s 4ms/step - loss: 4.2087e-04 - val_loss: 3.0794e-05
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_30 (LSTM)              (None, 50)                11600
#
#  dropout_28 (Dropout)        (None, 50)                0
#
#  dense_28 (Dense)            (None, 2)                 102
#
# =================================================================
# Total params: 11,702
# Trainable params: 11,702
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train2.shape
# Out:
# (99483, 1, 7)

# %%
# make predictions
train_predict = model.predict(X_train2)
test_predict = model.predict(X_test2)

# %%
train_predict.shape
train_predict=np.delete(train_predict,1,1) #1,1 1st 1 represents 2nd(0,1) and 2nd 1 represents axis =1 ie vertical ie columns
train_predict;

# %%
test_predict=np.delete(test_predict,1,1) #1,1 1st 1 represents 2nd(0,1) and 2nd 1 represents axis =1 ie vertical ie columns

test_predict
# Out:
# array([[0.6280565 ],
#        [0.42757952],
#        [0.696097  ],
#        ...,
#        [0.693224  ],
#        [0.74158275],
#        [0.6959391 ]], dtype=float32)

# %%
y_train.shape
# Out:
# (99483,)

# %%
z = np.zeros((train_predict.shape[0],6), dtype=np.int64)
train_predict2=np.append(train_predict, z, axis=1)
train_predict2.shape

z = np.zeros((test_predict.shape[0],6), dtype=np.int64)
test_predict2=np.append(test_predict, z, axis=1)
test_predict2.shape
# Out:
# (42636, 7)

# %%
# invert predictions

train_predict3 = scaler.inverse_transform(train_predict2)
#y_train = scaler.inverse_transform([y_train])
test_predict3 = scaler.inverse_transform(test_predict2)
#y_test = scaler.inverse_transform([y_test])

# %%
train_predict3[:,0]
# Out:
# array([ 82415.43274671,  91840.0323569 ,  88208.78017347, ...,
#        112183.10171414,  97552.58422523, 121015.51751338])

# %%
print('Train Mean Absolute Error:', mean_absolute_error(y_train, train_predict3[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(y_train, train_predict3[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(y_test, test_predict3[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test, test_predict3[:,0])))
# Out:
# Train Mean Absolute Error: 11.453442197468085
# Train Root Mean Squared Error: 11.593147864563859
# Test Mean Absolute Error: 11.45505616150862
# Test Root Mean Squared Error: 11.59259781290322

# %%
y_test3[1:5]
# Out:
# array([0.42418453, 0.70184814, 0.61028401, 0.74407392])

# %%
test_predict3.shape
# Out:
# (42636, 8)

# %%
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
aa=[x for x in range(200)]
plt.figure(figsize=(20,15))
plt.plot(aa, y_test3[:200], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:200], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('SOC', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();
